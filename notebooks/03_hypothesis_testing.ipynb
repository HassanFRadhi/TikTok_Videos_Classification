# %% [markdown]
# # **Classification of Claims in TikTok Videos**
# **Third Stage - Hyopthesis Testing**

# %% [markdown]
# Situation: The current project is reaching its midpoint; a project proposal, Python coding work, and exploratory data analysis have all been completed.
#
# Our next task is to determine and conduct the necessary hypothesis tests and statistical analysis for the TikTok classification project.

# %% [markdown]
# # **Data exploration and hypothesis testing**
#
# In this activity, we will explore the data and conduct hypothesis testing.
# <br/>
#
# **The purpose** of this stage is to prepare, create, and analyze hypothesis tests.
#
# **The goal** is to apply descriptive and inferential statistics, probability distributions, and hypothesis testing in Python.
# <br/>
#
# *This stage has three parts:*
#
# **Part 1:** Imports and data loading. <br>
# **Part 2:** Conducting hypothesis testing. <br>
# **Part 3:** Communicating insights with stakeholders. <br>

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# Throughout this notebook, we'll use references to the problem-solving framework PACE: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# ## **PACE: Plan**

# %% [markdown]
# The Question : Is there a relation between video views and author verification status? Is the relation statistically significant?

# %% [markdown]
# ### **Part 1. Imports and Data Loading**

# %% [markdown]
# We'll Import packages and libraries needed to compute descriptive statistics and conduct a hypothesis test.

# %%
# Importing packages for data manipulation

import pandas as pd
import numpy as np

# Importing packages for data visualization

import matplotlib.pyplot as plt
import seaborn as sns
# Importing packages for statistical analysis/hypothesis testing

from scipy import stats

# %%
# Loading dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv",index_col=0)

# %% [markdown]
# ## **PACE: Analyze and Construct**

# %% [markdown]
# We use describtive statistics to identify center and dispertion of the data which help us detrmine main data characteristics and distribution as quickly as possible.

# %% [markdown]
# ### **Part 2. Data exploration**
#
# We'll use descriptive statistics to conduct Exploratory Data Analysis (EDA).

# %%
# Displaying first few rows

data.head(10)
# Out:
#    claim_status    video_id  video_duration_sec  \
# #
# 1         claim  7017666017                  59
# 2         claim  4014381136                  32
# 3         claim  9859838091                  31
# 4         claim  1866847991                  25
# 5         claim  7105231098                  19
# 6         claim  8972200955                  35
# 7         claim  4958886992                  16
# 8         claim  2270982263                  41
# 9         claim  5235769692                  50
# 10        claim  4660861094                  45
#
#                              video_transcription_text verified_status  \
# #
# 1   someone shared with me that drone deliveries a...    not verified
# 2   someone shared with me that there are more mic...    not verified
# 3   someone shared with me that american industria...    not verified
# 4   someone shared with me that the metro of st. p...    not verified
# 5   someone shared with me that the number of busi...    not verified
# ...

# %%
# Generating a table of descriptive statistics about the data

data.describe(include='all')
# Out:
#        claim_status      video_id  video_duration_sec  \
# count         19084  1.938200e+04        19382.000000
# unique            2           NaN                 NaN
# top           claim           NaN                 NaN
# freq           9608           NaN                 NaN
# mean            NaN  5.627454e+09           32.421732
# std             NaN  2.536440e+09           16.229967
# min             NaN  1.234959e+09            5.000000
# 25%             NaN  3.430417e+09           18.000000
# 50%             NaN  5.618664e+09           32.000000
# 75%             NaN  7.843960e+09           47.000000
# max             NaN  9.999873e+09           60.000000
#
#                                  video_transcription_text verified_status  \
# count                                               19084           19382
# unique                                              19012               2
# top     a friend read  in the media a claim that badmi...    not verified
# ...

# %%
# Checking for missing values

data.isna().sum()
# Out:
# claim_status                0
# video_id                    0
# video_duration_sec          0
# video_transcription_text    0
# verified_status             0
# author_ban_status           0
# video_view_count            0
# video_like_count            0
# video_share_count           0
# video_download_count        0
# video_comment_count         0
# dtype: int64

# %%
# Droping rows with missing values


data = data.dropna().reset_index(drop=True)

# %%
# Displaying first few rows after handling missing values


data.head()
# Out:
#   claim_status    video_id  video_duration_sec  \
# #
# 1        claim  7017666017                  59
# 2        claim  4014381136                  32
# 3        claim  9859838091                  31
# 4        claim  1866847991                  25
# 5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# #
# 1  someone shared with me that drone deliveries a...    not verified
# 2  someone shared with me that there are more mic...    not verified
# 3  someone shared with me that american industria...    not verified
# 4  someone shared with me that the metro of st. p...    not verified
# 5  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# #
# 1      under review          343296.0           19425.0              241.0
# 2            active          140877.0           77355.0            19034.0
# ...

# %% [markdown]
# We are interested in the relationship between `verified_status` and `video_view_count`. One approach is to examine the mean value of `video_view_count` for each group of `verified_status` in the sample data.

# %%
# Computing the mean `video_view_count` for each group in `verified_status`

data.groupby('verified_status')['video_view_count'].mean()
# Out:
# verified_status
# not verified    265663.785339
# verified         91439.164167
# Name: video_view_count, dtype: float64

# %% [markdown]
# ### **Part 3. Hypothesis testing**

# %% [markdown]
# **Null hypothesis:** There is no effect of aouthor verification status on number of video views. <br>
# **Alternative hypothesis:** There is an effect of aouthor verification status on number of video views.

# %% [markdown]
# Our goal in this step is to conduct a two-sample t-test. The steps for conducting a hypothesis test are:
#
#
# 1.   Stating the null hypothesis and the alternative hypothesis
# 2.   Choosing a signficance level
# 3.   Finding the p-value
# 4.   Rejecting or failing to reject the null hypothesis

# %% [markdown]
# $H_0$ : There is no effect of author verification status on number of video views.<br>
# $H_a$ : There is an effect of author verification status on number of video views.

# %% [markdown]
# We choosed 5% as the significance level and proceed with a two-sample t-test.

# %%
# Conduct a two-sample t-test to compare means

verified = data[data['verified_status']=='verified']['video_view_count']
not_verified = data[data['verified_status']=='not verified']['video_view_count']
stats.ttest_ind(a=verified,b=not_verified, equal_var=False)
# Out:
# Ttest_indResult(statistic=-25.499441780633777, pvalue=2.6088823687177823e-120)

# %% [markdown]
# P-value = $2.6*10^{-120}$ which is much smaller than the significance level. Therfore, we `reject` the null hypothesis.

# %% [markdown]
# ## **PACE: Execute**

# %% [markdown]
# ## **Part 4: Communicating insights with stakeholders**

# %% [markdown]
# We can conclude that there is a strong effect of author verification status on number of video views which is by the way correlated with claim status. Where not verified authors tend to get much more views on average.
